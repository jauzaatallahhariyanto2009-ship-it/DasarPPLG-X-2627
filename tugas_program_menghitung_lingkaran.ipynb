# %% [markdown]
# <a href="https://colab.research.google.com/github/jauzaatallahhariyanto2009-ship-it/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_lingkaran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luas_lingkaran.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float r, luas;
#
#     cout << "Program menghitung luas lingkaran" << endl;
#     cout << "Masukkan jari-jari: ";
#     cin >> r;
#
#     luas = 3.14 * r * r;
#
#     cout << "Luas lingkaran = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting luas_lingkaran.cpp

# %%
# !g++ luas_lingkaran.cpp -o main

# %%
! ./main
# Out:
# Program menghitung luas lingkaran
# Masukkan jari-jari: 7
# Luas lingkaran = 153.86
